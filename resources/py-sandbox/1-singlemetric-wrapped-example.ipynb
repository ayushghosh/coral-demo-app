# %% [markdown]
# ## Context
# In this notebook, we simply wrap the gcm tutorial into a class / method, so we can take in data and output attribution results.

# %% [markdown]
# ## Imports

# %%
from causal_analyzer import CausalImpactAnalyzer

# %% [markdown]
# ## Workspace

# %% [markdown]
# ### Specify data paths

# %%
data_dir = "simulated_singlemetric_data"
normal_data_path = f"{data_dir}/rca_microservice_architecture_latencies.csv"
outlier_data_path = f"{data_dir}/rca_microservice_architecture_anomaly_1000.csv"
causal_graph_path = f"{data_dir}/causal_graph.json"
target_node_path = f"{data_dir}/target_node.txt"

# %% [markdown]
# ### Run analysis

# %%
# Create an instance of the CausalImpactAnalyzer
analyzer = CausalImpactAnalyzer()

# Load data and identify attributions
median_attribs, uncertainty_attribs = analyzer.load_and_identify_attributions(
    normal_data_path, 
    outlier_data_path, 
    causal_graph_path, 
    target_node_path, 
)

# Plot the attributions
plot_bytes = analyzer.plot_attributions(median_attribs, uncertainty_attribs)
# Out:
# /Users/by-gc-ia/opt/anaconda3/envs/py-dowhy/lib/python3.11/site-packages/networkx/readwrite/json_graph/node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# Estimating Shapley Values. Average change of Shapley values in run 118 (590 evaluated permutations): 2.5462366442114335%: 100%|██████████| 1/1 [00:05<00:00,  5.67s/it]
# Estimating Shapley Values. Average change of Shapley values in run 241 (1205 evaluated permutations): 1.3124963252570176%: 100%|██████████| 1/1 [00:06<00:00,  6.57s/it]
# Estimating bootstrap interval...: 100%|██████████| 2/2 [00:23<00:00, 11.52s/it]
